# %%
import pandas as pd
df = pd.read_csv("D:\\economic_outlook\\raw_data\\fred_raw.csv")
print(df.shape)
print(df["indicator"].value_counts())
print(df.head())
print(df.tail())
# Out:
# (16207, 4)
# indicator
# yield_curve_spread       6938
# credit_spread            6937
# unemployment_rate         318
# sahm_rule                 318
# cpi_headline              318
# core_pce                  318
# consumer_sentiment        318
# industrial_production     318
# housing_starts            318
# real_gdp                  106
# Name: count, dtype: int64
#          date  value series_id           indicator
# 0  2000-01-03   1.10    T10Y3M  yield_curve_spread
# 1  2000-01-04   1.06    T10Y3M  yield_curve_spread
# 2  2000-01-05   1.18    T10Y3M  yield_curve_spread
# 3  2000-01-06   1.16    T10Y3M  yield_curve_spread
# 4  2000-01-07   1.14    T10Y3M  yield_curve_spread
#              date      value series_id indicator
# 16202  2025-04-01  23770.976     GDPC1  real_gdp
# 16203  2025-07-01  24026.834     GDPC1  real_gdp
# 16204  2025-10-01  24055.749     GDPC1  real_gdp
# 16205  2026-01-01  24180.419     GDPC1  real_gdp
# 16206  2026-04-01  24270.599     GDPC1  real_gdp
